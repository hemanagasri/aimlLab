# %% [markdown]
# <a href="https://colab.research.google.com/github/hemanagasri/aimlLab/blob/main/ml1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_csv('auto-mpg.csv')
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
data.shape
# Out:
# (398, 9)

# %%
data.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      5
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
data.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    393 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
data.var()
# Out:
# <ipython-input-30-6bf595b3cfe5>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.var()
# mpg                 61.089611
# cylinders            2.893415
# displacement     10872.199152
# weight          717140.990526
# acceleration         7.604848
# model year          13.672443
# origin               0.643292
# dtype: float64

# %%
print(data.mode())
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  13.0        4.0          97.0        150    1985          14.5        73.0
# 1   NaN        NaN           NaN        NaN    2130           NaN         NaN
#
#    origin    car name
# 0     1.0  ford pinto
# 1     NaN         NaN

# %%
import numpy as np

column_name='horsepower'
data[column_name] = data[column_name].replace('?',np.nan)
data['horsepower']=data['horsepower'].astype(float)
mean_value=data['horsepower'].mean()
data['horsepower'].fillna(value=mean_value, inplace=True)
print(data[column_name].describe())
print(data.describe())
# Out:
# count    398.000000
# mean     104.469388
# std       38.199187
# min       46.000000
# 25%       76.000000
# 50%       95.000000
# 75%      125.000000
# max      230.000000
# Name: horsepower, dtype: float64
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  398.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.199187   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   76.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   95.000000  2803.500000
# 75%     29.000000    8.000000    262.000000  125.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model year      origin
# count    398.000000  398.000000  398.000000
# mean      15.568090   76.010050    1.572864
# ...

# %%
data.median()
# Out:
# <ipython-input-33-135339ac59ce>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.median()
# mpg               23.0
# cylinders          4.0
# displacement     148.5
# horsepower        95.0
# weight          2803.5
# acceleration      15.5
# model year        76.0
# origin             1.0
# dtype: float64

# %%
data.var()
# Out:
# <ipython-input-34-6bf595b3cfe5>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.var()
# mpg                 61.089611
# cylinders            2.893415
# displacement     10872.199152
# horsepower        1459.177916
# weight          717140.990526
# acceleration         7.604848
# model year          13.672443
# origin               0.643292
# dtype: float64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
data.boxplot()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
plt.boxplot(data['weight'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x79fbdf2e4640>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x79fbdf2e5ff0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x79fbdf2e5930>],
#  'medians': [<matplotlib.lines.Line2D at 0x79fbdf2e6530>],
#  'fliers': [<matplotlib.lines.Line2D at 0x79fbdf2e67d0>],
#  'means': []}

# %%
# Draw a vertical boxplot grouped
# by a categorical variable:
import seaborn as sns
sns.set_style("whitegrid")

sns.boxplot( data = data)
# Out:
# <Axes: >

# %%
import numpy as np

# Example data
#data = [12, 16, 20, 24, 28, 32, 36, 40, 44, 48]

# Calculating quartiles
q1 = np.percentile(data['mpg'], 25)
q2 = np.percentile(data['mpg'], 50)
q3 = np.percentile(data['mpg'], 75)

print("First Quartile (Q1):", q1)
print("Second Quartile (Q2 - Median):", q2)
print("Third Quartile (Q3):", q3)
print("iqr ",q3-q1)
# Out:
# First Quartile (Q1): 17.5
# Second Quartile (Q2 - Median): 23.0
# Third Quartile (Q3): 29.0
# iqr  11.5

# %%
# Using Seaborn
# Assuming your dataset has multiple columns (attributes
df=data.iloc[:,:-1]
print(df.columns)
for column in df.columns:
    plt.figure()  # Create a new figure for each attribute
    #df.boxplot(column=column)
    plt.boxplot(df[column], showfliers=True)
    plt.title(f'Boxplot of {column}')
    plt.ylabel(column)
    plt.show()
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin'],
#       dtype='object')

# %%
for column in df.columns:
    plt.figure()  # Create a new figure for each attribute
    plt.hist(df[column],bins=10)
    plt.title(f'histogram of {column}')
    plt.ylabel(column)
    plt.show()

# %%
sns.pairplot(data)

# %%
for attribute in df.columns:
  Q1 = df[attribute].quantile(0.25)
  Q3 = df[attribute].quantile(0.75)
  IQR = Q3 - Q1
  lower_bound = Q1 - 1.5 * IQR
  upper_bound = Q3 + 1.5 * IQR
  print("lower_bound",lower_bound)
  print("upper_bound",upper_bound)
  outliers = df[(df[attribute] < lower_bound) | (df[attribute] > upper_bound)]
  print("Outliers:")
  print(outliers[[attribute]].count())
  print(outliers[[attribute]])
  # Cap the outliers below the lower bound to the lower bound value
  df.loc[df[attribute] < lower_bound, attribute] = lower_bound

  # Cap the outliers above the upper bound to the upper bound value
  df.loc[df[attribute] > upper_bound, attribute] = upper_bound
# Out:
# lower_bound 0.25
# upper_bound 46.25
# Outliers:
# mpg    1
# dtype: int64
#       mpg
# 322  46.6
# lower_bound -2.0
# upper_bound 14.0
# Outliers:
# cylinders    0
# dtype: int64
# Empty DataFrame
# Columns: [cylinders]
# Index: []
# lower_bound -132.375
# upper_bound 498.625
# Outliers:
# displacement    0
# dtype: int64
# Empty DataFrame
# Columns: [displacement]
# Index: []
# lower_bound 2.5
# upper_bound 198.5
# Outliers:
# horsepower    11
# dtype: int64
#      horsepower
# 6         220.0
# 7         215.0
# 8         225.0
# 13        225.0
# 25        215.0
# 26        200.0
# 27        210.0
# 67        208.0
# 94        215.0
# 95        225.0
# 116       230.0
# lower_bound 147.375
# upper_bound 5684.375
# Outliers:
# weight    0
# dtype: int64
# Empty DataFrame
# Columns: [weight]
# Index: []
# lower_bound 8.8
# upper_bound 22.2
# Outliers:
# acceleration    7
# dtype: int64
#      acceleration
# 7             8.5
# 9             8.5
# 11            8.0
# ...

# %%
plt.scatter(df['acceleration'],df['horsepower'])

# %%
for column in df.columns:
    plt.figure()  # Create a new figure for each attribute
    #df.boxplot(column=column)
    plt.boxplot(df[column])
    plt.title(f'Boxplot of {column}')
    plt.ylabel(column)
    plt.show()
